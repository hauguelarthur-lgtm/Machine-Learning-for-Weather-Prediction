# %%
import xarray as xr
import numpy as np
import pandas as pd

pressuretest = xr.open_dataset("era5_france_raw/pressure_1996_01.nc")
#surfacetest = xr.open_dataset("era5_france_raw/surface_1996_01.nc")

# %%
datatest.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	valid_time = 124 ;
# 	pressure_level = 4 ;
# 	latitude = 64 ;
# 	longitude = 64 ;
#
# variables:
# 	float32 z(valid_time, pressure_level, latitude, longitude) ;
# 		z:GRIB_paramId = 129 ;
# 		z:GRIB_dataType = an ;
# 		z:GRIB_numberOfPoints = 4096 ;
# 		z:GRIB_typeOfLevel = isobaricInhPa ;
# 		z:GRIB_stepUnits = 1 ;
# 		z:GRIB_stepType = instant ;
# 		z:GRIB_gridType = regular_ll ;
# 		z:GRIB_uvRelativeToGrid = 0 ;
# 		z:GRIB_NV = 0 ;
# 		z:GRIB_Nx = 64 ;
# 		z:GRIB_Ny = 64 ;
# 		z:GRIB_cfName = geopotential ;
# 		z:GRIB_cfVarName = z ;
# 		z:GRIB_gridDefinitionDescription = Latitude/Longitude Grid ;
# 		z:GRIB_iDirectionIncrementInDegrees = 0.25 ;
# 		z:GRIB_iScansNegatively = 0 ;
# 		z:GRIB_jDirectionIncrementInDegrees = 0.25 ;
# 		z:GRIB_jPointsAreConsecutive = 0 ;
# 		z:GRIB_jScansPositively = 0 ;
# 		z:GRIB_latitudeOfFirstGridPointInDegrees = 54.5 ;
# 		z:GRIB_latitudeOfLastGridPointInDegrees = 38.75 ;
# ...

# %%
surfacetest = xr.open_dataset("era5_france_raw/data_stream-oper_stepType-accum.nc")
surfacetest2 = xr.open_dataset("era5_france_raw/data_stream-oper_stepType-instant.nc")
surfacetest.info()
surfacetest2.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	valid_time = 124 ;
# 	latitude = 64 ;
# 	longitude = 64 ;
#
# variables:
# 	float32 tp(valid_time, latitude, longitude) ;
# 		tp:GRIB_paramId = 228 ;
# 		tp:GRIB_dataType = fc ;
# 		tp:GRIB_numberOfPoints = 4096 ;
# 		tp:GRIB_typeOfLevel = surface ;
# 		tp:GRIB_stepUnits = 1 ;
# 		tp:GRIB_stepType = accum ;
# 		tp:GRIB_gridType = regular_ll ;
# 		tp:GRIB_uvRelativeToGrid = 0 ;
# 		tp:GRIB_NV = 0 ;
# 		tp:GRIB_Nx = 64 ;
# 		tp:GRIB_Ny = 64 ;
# 		tp:GRIB_cfName = unknown ;
# 		tp:GRIB_cfVarName = tp ;
# 		tp:GRIB_gridDefinitionDescription = Latitude/Longitude Grid ;
# 		tp:GRIB_iDirectionIncrementInDegrees = 0.25 ;
# 		tp:GRIB_iScansNegatively = 0 ;
# 		tp:GRIB_jDirectionIncrementInDegrees = 0.25 ;
# 		tp:GRIB_jPointsAreConsecutive = 0 ;
# 		tp:GRIB_jScansPositively = 0 ;
# 		tp:GRIB_latitudeOfFirstGridPointInDegrees = 54.5 ;
# 		tp:GRIB_latitudeOfLastGridPointInDegrees = 38.75 ;
# 		tp:GRIB_longitudeOfFirstGridPointInDegrees = -6.25 ;
# ...

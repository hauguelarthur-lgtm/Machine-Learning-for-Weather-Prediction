# %%
import xarray as xr
import numpy as np
import pandas as pd

test = xr.open_dataset("data/processed/engineered_1996.nc")

# %%
test.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	valid_time = 1464 ;
# 	latitude = 64 ;
# 	longitude = 64 ;
#
# variables:
# 	float32 v10_mag(valid_time, latitude, longitude) ;
# 		v10_mag:GRIB_dataType = an ;
# 		v10_mag:GRIB_numberOfPoints = 4096 ;
# 		v10_mag:GRIB_typeOfLevel = surface ;
# 		v10_mag:GRIB_stepUnits = 1 ;
# 		v10_mag:GRIB_stepType = instant ;
# 		v10_mag:GRIB_gridType = regular_ll ;
# 		v10_mag:GRIB_uvRelativeToGrid = 0 ;
# 		v10_mag:GRIB_NV = 0 ;
# 		v10_mag:GRIB_Nx = 64 ;
# 		v10_mag:GRIB_Ny = 64 ;
# 		v10_mag:GRIB_cfName = unknown ;
# 		v10_mag:GRIB_gridDefinitionDescription = Latitude/Longitude Grid ;
# 		v10_mag:GRIB_iDirectionIncrementInDegrees = 0.25 ;
# 		v10_mag:GRIB_iScansNegatively = 0 ;
# 		v10_mag:GRIB_jDirectionIncrementInDegrees = 0.25 ;
# 		v10_mag:GRIB_jPointsAreConsecutive = 0 ;
# 		v10_mag:GRIB_jScansPositively = 0 ;
# 		v10_mag:GRIB_latitudeOfFirstGridPointInDegrees = 54.5 ;
# 		v10_mag:GRIB_latitudeOfLastGridPointInDegrees = 38.75 ;
# ...

# %%
 print(len(list(test.data_vars.keys())))
# Out:
# 42
